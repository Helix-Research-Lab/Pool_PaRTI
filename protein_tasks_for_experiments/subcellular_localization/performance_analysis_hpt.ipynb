# %%
with open("logs_efficient/test_logs/cls_pooled/1.txt", 'r') as file:
    line = file.readlines()[-1]
splitLine = line.split('- ')[1].split(', ')

# %%
import os
import pandas as pd
import importlib

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import performance_utils_SCL
importlib.reload(performance_utils_SCL)
# Out:
# <module 'performance_utils_SCL' from '/oak/stanford/groups/rbaltman/alptartici/substrateSpec/pooling_performances/localization_task/model_localization/performance_utils_SCL.py'>

# %% [markdown]
# # looking at MCC

# %%
df = performance_utils_SCL.extract_global_metrics('cls_pooled', 'mcc')
print(len(df))
df
# Out:
# 36
#     run_no    loss  f1_micro  f1_macro     mcc  hamming_loss  hamming_acc  \
# 12      60  0.8861    0.6180    0.3871  0.3095        0.1240       0.8760
# 2       70  1.0679    0.5970    0.3865  0.2982        0.1541       0.8459
# 6       69  0.8871    0.6089    0.3769  0.2965        0.1253       0.8747
# 5       57  0.8954    0.6004    0.3780  0.2913        0.1403       0.8597
# 23     114  0.8956    0.6030    0.3780  0.2895        0.1406       0.8594
# 0      123  0.8886    0.6090    0.3704  0.2869        0.1271       0.8729
# 14      61  1.0673    0.5967    0.3788  0.2781        0.1504       0.8496
# 21     116  1.3517    0.5215    0.3494  0.2651        0.2198       0.7802
# 16      68  1.3589    0.5235    0.3499  0.2627        0.2195       0.7805
# 27     124  1.0759    0.5833    0.3672  0.2607        0.1600       0.8400
# 3       62  1.3520    0.5160    0.3458  0.2594        0.2224       0.7776
# 9       67  1.0628    0.5818    0.3637  0.2585        0.1577       0.8423
# ...

# %%
df = performance_utils_SCL.extract_global_metrics('mean_pooled', 'mcc')
print(len(df))
df
# Out:
# 36
#     run_no    loss  f1_micro  f1_macro     mcc  hamming_loss  hamming_acc  \
# 5       57  0.9062    0.5792    0.2368  0.3125        0.1369       0.8631
# 24     111  0.8920    0.5951    0.3798  0.2962        0.1310       0.8690
# 14      61  1.0730    0.5946    0.3781  0.2945        0.1475       0.8525
# 0      123  0.8920    0.6033    0.3745  0.2875        0.1336       0.8664
# 35     125  1.3522    0.5440    0.3665  0.2858        0.2038       0.7962
# 13     121  1.0732    0.5892    0.3685  0.2853        0.1529       0.8471
# 28      66  0.8935    0.5872    0.3682  0.2819        0.1359       0.8641
# 10      71  1.3545    0.5377    0.3622  0.2778        0.2070       0.7930
# 6       69  0.8930    0.5865    0.3645  0.2771        0.1344       0.8656
# 27     124  1.1502    0.5421    0.1567  0.2769        0.1567       0.8433
# 16      68  1.3486    0.5431    0.3564  0.2765        0.2011       0.7989
# 17     112  1.0711    0.5908    0.3730  0.2734        0.1510       0.8490
# ...

# %%
df = performance_utils_SCL.extract_global_metrics('max_pooled', 'mcc')
print(len(df))
df
# Out:
# 36
#     run_no    loss  f1_micro  f1_macro     mcc  hamming_loss  hamming_acc  \
# 2       70  1.1923    0.2943    0.0671  0.2325        0.1761       0.8239
# 28      66  0.9543    0.1300    0.0432  0.1143        0.1574       0.8426
# 4      120  0.9550    0.0895    0.0333  0.1084        0.1547       0.8453
# 6       69  0.9550    0.0845    0.0318  0.1009        0.1548       0.8452
# 0      123  0.9550    0.0748    0.0290  0.0418        0.1544       0.8456
# 17     112  1.1973    0.0712    0.0379  0.0365        0.1581       0.8419
# 14      61  1.1973    0.0112    0.0129  0.0031        0.1595       0.8405
# 24     111  0.9550    0.0112    0.0127 -0.0009        0.1752       0.8248
# 13     121  1.1973    0.0022    0.0030 -0.0375        0.1620       0.8380
# 12      60  0.9550    0.0122    0.0085 -0.0453        0.1613       0.8387
# 9       67  1.1973    0.0815    0.0214 -0.0628        0.1550       0.8450
# 23     114  0.9550    0.0987    0.0254 -0.0643        0.1552       0.8448
# ...

# %%
df = performance_utils_SCL.extract_global_metrics('PR_contact_prune_topk_no_enh', 'mcc')
print(len(df))
df
# Out:
# 36
#     run_no    loss  f1_micro  f1_macro     mcc  hamming_loss  hamming_acc  \
# 6       69  0.9019    0.5774    0.2810  0.3222        0.1313       0.8687
# 8       52  1.1512    0.4725    0.0904  0.3111        0.1345       0.8655
# 12      60  0.9033    0.5685    0.2757  0.3049        0.1362       0.8638
# 14      61  1.0701    0.5990    0.3862  0.3036        0.1486       0.8514
# 4      120  0.8916    0.5977    0.3892  0.3008        0.1340       0.8660
# 0      123  0.8923    0.5933    0.3866  0.2976        0.1353       0.8647
# 7      106  1.1408    0.5587    0.2027  0.2901        0.1509       0.8491
# 13     121  1.0716    0.5851    0.3748  0.2873        0.1533       0.8467
# 21     116  1.3428    0.5509    0.3670  0.2873        0.1953       0.8047
# 15     113  1.3439    0.5477    0.3659  0.2865        0.1969       0.8031
# 35     125  1.3433    0.5459    0.3640  0.2843        0.2003       0.7997
# 11     122  1.3443    0.5439    0.3618  0.2826        0.2031       0.7969
# ...

# %% [markdown]
# ## looking at hamming accuracy

# %%
df = performance_utils_SCL.extract_global_metrics('cls_pooled', 'hamming_acc')
print(len(df))
df
# Out:
# 36
#     run_no    loss  f1_micro  f1_macro     mcc  hamming_loss  hamming_acc  \
# 12      60  0.8861    0.6180    0.3871  0.3095        0.1240       0.8760
# 6       69  0.8871    0.6089    0.3769  0.2965        0.1253       0.8747
# 0      123  0.8886    0.6090    0.3704  0.2869        0.1271       0.8729
# 5       57  0.8954    0.6004    0.3780  0.2913        0.1403       0.8597
# 23     114  0.8956    0.6030    0.3780  0.2895        0.1406       0.8594
# 32     115  1.1575    0.4647    0.0852     NaN        0.1488       0.8512
# 8       52  1.1575    0.4647    0.0852     NaN        0.1488       0.8512
# 17     112  1.1973    0.1268    0.0328  0.0641        0.1495       0.8505
# 28      66  0.9550    0.1531    0.0382  0.0423        0.1501       0.8499
# 14      61  1.0673    0.5967    0.3788  0.2781        0.1504       0.8496
# 2       70  1.0679    0.5970    0.3865  0.2982        0.1541       0.8459
# 9       67  1.0628    0.5818    0.3637  0.2585        0.1577       0.8423
# ...

# %%
df = performance_utils_SCL.extract_global_metrics('PR_contact_prune_topk_no_enh', 'hamming_acc')
print(len(df))
df
# Out:
# 36
#     run_no    loss  f1_micro  f1_macro     mcc  hamming_loss  hamming_acc  \
# 6       69  0.9019    0.5774    0.2810  0.3222        0.1313       0.8687
# 4      120  0.8916    0.5977    0.3892  0.3008        0.1340       0.8660
# 8       52  1.1512    0.4725    0.0904  0.3111        0.1345       0.8655
# 0      123  0.8923    0.5933    0.3866  0.2976        0.1353       0.8647
# 12      60  0.9033    0.5685    0.2757  0.3049        0.1362       0.8638
# 31      58  1.1497    0.4641    0.1280  0.2471        0.1383       0.8617
# 26     104  1.6155    0.3879    0.1146  0.1711        0.1482       0.8518
# 9       67  1.0715    0.5957    0.3764  0.2762        0.1483       0.8517
# 14      61  1.0701    0.5990    0.3862  0.3036        0.1486       0.8514
# 7      106  1.1408    0.5587    0.2027  0.2901        0.1509       0.8491
# 5       57  0.9550    0.0443    0.0125  0.0259        0.1520       0.8480
# 18      48  0.9550    0.0432    0.0121  0.0192        0.1522       0.8478
# ...

# %%
df = performance_utils_SCL.extract_global_metrics('mean_pooled', 'hamming_acc')
print(len(df))
df
# Out:
# 36
#     run_no    loss  f1_micro  f1_macro     mcc  hamming_loss  hamming_acc  \
# 24     111  0.8920    0.5951    0.3798  0.2962        0.1310       0.8690
# 0      123  0.8920    0.6033    0.3745  0.2875        0.1336       0.8664
# 6       69  0.8930    0.5865    0.3645  0.2771        0.1344       0.8656
# 28      66  0.8935    0.5872    0.3682  0.2819        0.1359       0.8641
# 5       57  0.9062    0.5792    0.2368  0.3125        0.1369       0.8631
# 14      61  1.0730    0.5946    0.3781  0.2945        0.1475       0.8525
# 17     112  1.0711    0.5908    0.3730  0.2734        0.1510       0.8490
# 13     121  1.0732    0.5892    0.3685  0.2853        0.1529       0.8471
# 23     114  0.9550    0.1008    0.0372  0.1457        0.1533       0.8467
# 34      59  1.5875    0.5128    0.1748  0.1869        0.1535       0.8465
# 25      50  1.6657    0.0385    0.0299  0.2003        0.1537       0.8463
# 31      58  1.0764    0.5881    0.3636  0.2626        0.1542       0.8458
# ...

# %%
df = performance_utils_SCL.extract_global_metrics('max_pooled', 'hamming_acc')
print(len(df))
df
# Out:
# 36
#     run_no    loss  f1_micro  f1_macro     mcc  hamming_loss  hamming_acc  \
# 0      123  0.9550    0.0748    0.0290  0.0418        0.1544       0.8456
# 4      120  0.9550    0.0895    0.0333  0.1084        0.1547       0.8453
# 6       69  0.9550    0.0845    0.0318  0.1009        0.1548       0.8452
# 9       67  1.1973    0.0815    0.0214 -0.0628        0.1550       0.8450
# 23     114  0.9550    0.0987    0.0254 -0.0643        0.1552       0.8448
# 28      66  0.9543    0.1300    0.0432  0.1143        0.1574       0.8426
# 17     112  1.1973    0.0712    0.0379  0.0365        0.1581       0.8419
# 14      61  1.1973    0.0112    0.0129  0.0031        0.1595       0.8405
# 12      60  0.9550    0.0122    0.0085 -0.0453        0.1613       0.8387
# 13     121  1.1973    0.0022    0.0030 -0.0375        0.1620       0.8380
# 24     111  0.9550    0.0112    0.0127 -0.0009        0.1752       0.8248
# 2       70  1.1923    0.2943    0.0671  0.2325        0.1761       0.8239
# ...

# %% [markdown]
# ## label specific AUPRC

# %%
import performance_utils_SCL
importlib.reload(performance_utils_SCL)
# Out:
# <module 'performance_utils_SCL' from '/oak/stanford/groups/rbaltman/alptartici/substrateSpec/pooling_performances/localization_task/model_localization/performance_utils_SCL.py'>

# %%
performance_utils_SCL.get_label_specific_auprc('cls_pooled', 'avg')
# Out:
#     run_no  cell_mem  cytoplasm        ER     golgi  lysosome  mitochondrion  \
# 4       60  0.470832   0.517459  0.241001  0.332320  0.062500       0.708955
# 25      69  0.473257   0.508696  0.238229  0.321385  0.013605       0.706916
# 12      62  0.397211   0.516281  0.284324  0.201294  0.014286       0.665357
# 16     123  0.460533   0.509359  0.246550  0.298752  0.036364       0.716617
# 27      61  0.445713   0.508158  0.277853  0.334716  0.020408       0.701254
# 22      70  0.446751   0.514820  0.265724  0.294793  0.022472       0.705125
# 8       67  0.417919   0.525923  0.272697  0.256875  0.018018       0.667229
# 33      57  0.446163   0.348394  0.248094  0.271047  0.037736       0.691241
# 0      124  0.450839   0.338512  0.257605  0.329304  0.015748       0.711609
# 23     116  0.388894   0.496941  0.267755  0.181324  0.018018       0.688491
# 1       71  0.377608   0.517706  0.245785  0.203592  0.011173       0.675319
# ...

# %%
performance_utils_SCL.get_label_specific_auprc('PR_contact_prune_topk_no_enh', 'avg')
# Out:
#     run_no  cell_mem  cytoplasm        ER     golgi  lysosome  mitochondrion  \
# 3       68  0.495621   0.496124  0.296340  0.322876  0.222222       0.634161
# 23     116  0.508677   0.515645  0.262349  0.263446  0.057143       0.603531
# 17     125  0.496830   0.494187  0.293079  0.308720  0.111111       0.606090
# 26     113  0.490147   0.500761  0.254423  0.280328  0.066667       0.610666
# 1       71  0.493348   0.512313  0.263911  0.319557  0.074074       0.561216
# 29     121  0.501932   0.510377  0.275060  0.360133  0.043478       0.629678
# 0      124  0.493716   0.513886  0.265209  0.375189  0.020408       0.644338
# 7      122  0.495289   0.501800  0.233811  0.307309  0.071429       0.620171
# 22      70  0.497119   0.514433  0.240205  0.364999  0.019231       0.659812
# 27      61  0.508457   0.479929  0.232697  0.367014  0.039216       0.647988
# 8       67  0.508901   0.516696  0.258376  0.348499  0.019231       0.664800
# ...

# %%
performance_utils_SCL.get_label_specific_auprc('max_pooled', 'avg')
# Out:
#     run_no  cell_mem  cytoplasm        ER     golgi  lysosome  mitochondrion  \
# 22      70  0.146454   0.451435  0.045447  0.063625  0.001447       0.187960
# 14     120  0.146374   0.369149  0.047997  0.062428  0.001447       0.148192
# 15      66  0.145868   0.383485  0.045388  0.063121  0.001447       0.130970
# 16     123  0.149647   0.358342  0.047033  0.050651  0.001447       0.145839
# 7      122  0.150507   0.321274  0.048785  0.054010  0.001658       0.158735
# 25      69  0.150507   0.369237  0.047033  0.050651  0.001447       0.130970
# 6      112  0.150507   0.345132  0.047033  0.063389  0.001447       0.130970
# 10     111  0.150507   0.321274  0.046492  0.064708  0.001447       0.143500
# 26     113  0.154155   0.320783  0.050584  0.052937  0.001447       0.145998
# 12      62  0.146541   0.308332  0.046512  0.054694  0.001447       0.144987
# 3       68  0.147765   0.321274  0.049409  0.050798  0.001570       0.155970
# ...

# %%
performance_utils_SCL.get_label_specific_auprc('mean_pooled', 'avg')
# Out:
#     run_no  cell_mem  cytoplasm        ER     golgi  lysosome  mitochondrion  \
# 22      67  0.509257   0.512464  0.254946  0.386648  0.022222       0.668491
# 11     121  0.486438   0.524336  0.291468  0.338000  0.029412       0.648593
# 5       70  0.504408   0.518712  0.236623  0.380860  0.021277       0.648812
# 32      71  0.484370   0.320620  0.262149  0.312379  0.222222       0.610870
# 21      58  0.467952   0.485234  0.284952  0.336298  0.025974       0.636100
# 3       66  0.461697   0.510246  0.252577  0.360858  0.020000       0.654885
# 20     112  0.462399   0.510601  0.293739  0.346272  0.022989       0.658243
# 8      115  0.484411   0.499331  0.300105  0.376468  0.021978       0.623822
# 13      69  0.467663   0.512025  0.261511  0.325200  0.031250       0.662645
# 10      68  0.487233   0.492258  0.276134  0.233375  0.071429       0.617095
# 18      61  0.438068   0.511250  0.270408  0.328025  0.052632       0.650456
# ...

# %% [markdown]
# ## getting top 3

# %%
import performance_utils_SCL
importlib.reload(performance_utils_SCL)
# Out:
# <module 'performance_utils_SCL' from '/oak/stanford/groups/rbaltman/alptartici/substrateSpec/pooling_performances/localization_task/model_localization/performance_utils_SCL.py'>

# %%
pooling_methods = ['PR_contact_prune_topk_no_enh', 'cls_pooled', 'max_pooled', 'mean_pooled']

# %%
performance_utils_SCL.analyze_and_plot_single(pooling_methods, 'hamming_acc', top_k=3)
# Out:
#        run_no      loss  f1_micro  f1_macro       mcc  hamming_loss  \
# 1   84.000000  0.887267  0.611967  0.378133  0.297633      0.125467
# 3  101.000000  0.892333  0.594967  0.372933  0.286933      0.133000
# 0   80.333333  0.981567  0.549200  0.253533  0.311367      0.133267
# 2  104.000000  0.955000  0.082933  0.031367  0.083700      0.154633
#
#    hamming_acc  jaccard_ind  hamming_acc_std                        method
# 1     0.874533     0.534067         0.001557                    cls_pooled
# 3     0.867000     0.518300         0.001778                   mean_pooled
# 0     0.866733     0.472200         0.001721  PR_contact_prune_topk_no_enh
# 2     0.845367     0.043067         0.000208                    max_pooled

# %%
performance_utils_SCL.analyze_and_plot_single(pooling_methods, 'mcc-label-avg', top_k=3)
# Out:
#       run_no      loss  f1_micro  f1_macro       mcc  hamming_loss  \
# 0  60.333333  0.985467  0.539467  0.215700  0.312733      0.134000
# 1  66.333333  0.947033  0.607967  0.383500  0.301400      0.134467
# 3  76.333333  0.957067  0.589633  0.331567  0.301067      0.138467
# 2  85.333333  1.033867  0.171267  0.047867  0.151733      0.162733
#
#    hamming_acc  jaccard_ind  mcc-label-avg_std                        method
# 0     0.866000     0.455000           0.008765  PR_contact_prune_topk_no_enh
# 1     0.865533     0.527867           0.007066                    cls_pooled
# 3     0.861533     0.498733           0.009938                   mean_pooled
# 2     0.837267     0.108400           0.070008                    max_pooled

# %%
performance_utils_SCL.analyze_and_plot_single(pooling_methods, 'auprc-label-avg', top_k=3)
# Out:
#        run_no  cell_mem  cytoplasm        ER     golgi  lysosome  \
# 0  103.000000  0.500376   0.501985  0.283923  0.298347  0.130159
# 1   63.666667  0.447100   0.514145  0.254518  0.285000  0.030130
# 3   86.000000  0.500034   0.518504  0.261012  0.368503  0.024304
# 2   85.333333  0.146232   0.401357  0.046277  0.063058  0.001447
#
#    mitochondrion   nucleus  peroxisome    global       avg  \
# 0       0.614594  0.804766    0.485169  0.585530  0.452415
# 1       0.693743  0.822507    0.254508  0.602395  0.412706
# 3       0.655298  0.817257    0.103391  0.617359  0.406038
# 2       0.155707  0.509395    0.005065  0.215135  0.166067
#
#    auprc-label-avg_std                        method
# 0             0.035413  PR_contact_prune_topk_no_enh
# 1             0.006153                    cls_pooled
# 3             0.003586                   mean_pooled
# 2             0.007347                    max_pooled
